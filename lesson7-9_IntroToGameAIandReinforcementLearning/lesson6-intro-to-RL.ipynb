# %% [markdown]
# # 新的章节：强化学习！
#
# REF: https://www.kaggle.com/learn/intro-to-game-ai-and-reinforcement-learning
#
# 经过之前python编程和机器学习入门的课程，相信你已经学会了以下内容：
#
# 1. 了解Python编程语言的基本语法和基本数据类型
#
# 2. 了解机器学习的基本概念，包括数据集、特征、标签、模型、损失函数等（以及这些术语的英文名称！）
#
# 3. 了解如何使用Scikit-learn库进行机器学习的基本操作

# %% [markdown]
# ## 或许你会疑惑
#
# **Q: 为什么学会机器学习的中文术语还不够，还要掌握英文名称？**
#
# A：主要是因为程序里面的函数名和变量名都是用英文的，所以要熟悉英文的术语才能更好地理解程序的意思。
#
# 另外，人工智能这个领域最前沿的论文一般都是用英文写的，想要了解最新的技术和算法，英文的论文和技术报告等文本的阅读是必不可少的。

# %% [markdown]
# 在今天的课程开始之前，我们先来回顾一下我们在之前学到的内容。
#
# **作业验收：你讲我听**
#
# **topic：Introduction to Machine Learning**

# %% [markdown]
# --------------
# 今天复习了前三节，还有两节记得课下复习哦！
# --------------

# %% [markdown]
# 好了，回顾一下我们的目标：
#
# 1. 了解机器学习中的基本概念和术语
# 2. 了解强化学习中的基本概念和术语
# 3. 学会调用前沿的模型，访问他们开放的网页/应用，并了解API调用
# 4. 学会使用Python编程语言，掌握基本语法
# 5. 学会利用一些Python库进行数据处理和简单模型的搭建、训练和验证
# 6. 学会独立阅读论文/技术报告

# %% [markdown]
# ## 强化学习，启动！
#
# ### 强化学习的典型案例：
#
# 智能体玩flappy bird
# https://www.bilibili.com/video/BV1sG4y1L784/?spm_id_from=333.337.top_right_bar_window_history.content.click
#
# ![image.png](attachment:image.png)
#
# 先阅读教案
#
# https://www.kaggle.com/code/alexisbcook/play-the-game
#
# 回答以下问题：
#
# 1. 关于文中提到的游戏，它的规则是什么？（怎么操作？怎样算赢？）
# 2. 这个系列的教案的几个章节分别要讲什么
#
# 一些关键词：
#
# agent ： 智能体
#
# environment ： 环境
#
# state ： 状态
#
# action ： 动作
#
# reward ： 奖励
#
# policy ： 策略
#
# value function ： 价值函数
